# %% [markdown]
# # ***Visualizing Breast Cancer Diagnosis***<hr/>

# %% [markdown]
# ### ***Import Libraries***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('brca.csv')
data.head()
# Out:
#    id  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0   1       13.540         14.36           87.46      566.3          0.09779
# 1   2       13.080         15.71           85.63      520.0          0.10750
# 2   3        9.504         12.44           60.34      273.9          0.10240
# 3   4       13.030         18.42           82.61      523.8          0.08983
# 4   5        8.196         16.84           51.71      201.9          0.08600
#
#    compactness_mean  concavity_mean  concave_pts_mean  symmetry_mean  ...  \
# 0           0.08129         0.06664          0.047810         0.1885  ...
# 1           0.12700         0.04568          0.031100         0.1967  ...
# 2           0.06492         0.02956          0.020760         0.1815  ...
# 3           0.03766         0.02562          0.029230         0.1467  ...
# 4           0.05943         0.01588          0.005917         0.1769  ...
#
# ...

# %%
data.tail()
# Out:
#       id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  565        20.92         25.09           143.0     1347.0
# 565  566        21.56         22.39           142.0     1479.0
# 566  567        20.13         28.25           131.2     1261.0
# 567  568        16.60         28.08           108.3      858.1
# 568  569        20.60         29.33           140.1     1265.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_pts_mean  \
# 564          0.10990            0.2236         0.31740           0.14740
# 565          0.11100            0.1159         0.24390           0.13890
# 566          0.09780            0.1034         0.14400           0.09791
# 567          0.08455            0.1023         0.09251           0.05302
# 568          0.11780            0.2770         0.35140           0.15200
#
#      symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 564         0.2149  ...          29.41            179.1      1819.0
# ...

# %%
data.shape
# Out:
# (569, 32)

# %%
data.describe().T
# Out:
#                    count        mean         std         min         25%  \
# id                 569.0  285.000000  164.400426    1.000000  143.000000
# radius_mean        569.0   14.127292    3.524049    6.981000   11.700000
# texture_mean       569.0   19.289649    4.301036    9.710000   16.170000
# perimeter_mean     569.0   91.969033   24.298981   43.790000   75.170000
# area_mean          569.0  654.889104  351.914129  143.500000  420.300000
# smoothness_mean    569.0    0.096360    0.014064    0.052630    0.086370
# compactness_mean   569.0    0.104341    0.052813    0.019380    0.064920
# concavity_mean     569.0    0.088799    0.079720    0.000000    0.029560
# concave_pts_mean   569.0    0.048919    0.038803    0.000000    0.020310
# symmetry_mean      569.0    0.181162    0.027414    0.106000    0.161900
# fractal_dim_mean   569.0    0.062798    0.007060    0.049960    0.057700
# radius_se          569.0    0.405172    0.277313    0.111500    0.232400
# ...

# %%
data.diagnosis.unique()
# Out:
# array(['B', 'M'], dtype=object)

# %%
count = data['diagnosis'].value_counts()
print(count)
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
plt.bar(count.index, count.values, color=['g','y'])
plt.show()

# %%
print(data.columns)
# Out:
# Index(['id', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_pts_mean', 'symmetry_mean', 'fractal_dim_mean', 'radius_se',
#        'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_pts_se', 'symmetry_se',
#        'fractal_dim_se', 'radius_worst', 'texture_worst', 'perimeter_worst',
#        'area_worst', 'smoothness_worst', 'compactness_worst',
#        'concavity_worst', 'concave_pts_worst', 'symmetry_worst',
#        'fractal_dim_worst', 'diagnosis'],
#       dtype='object')

# %% [markdown]
# ## ***Clean and Prepare data***

# %%
data.drop('id', axis = 1,inplace=True)

# %%
data.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       13.540         14.36           87.46      566.3          0.09779
# 1       13.080         15.71           85.63      520.0          0.10750
# 2        9.504         12.44           60.34      273.9          0.10240
# 3       13.030         18.42           82.61      523.8          0.08983
# 4        8.196         16.84           51.71      201.9          0.08600
#
#    compactness_mean  concavity_mean  concave_pts_mean  symmetry_mean  \
# 0           0.08129         0.06664          0.047810         0.1885
# 1           0.12700         0.04568          0.031100         0.1967
# 2           0.06492         0.02956          0.020760         0.1815
# 3           0.03766         0.02562          0.029230         0.1467
# 4           0.05943         0.01588          0.005917         0.1769
#
#    fractal_dim_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %% [markdown]
# ## ***Check for Missing Values***

# %%
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
data_cleaned = data.dropna()
# Out:
# Missing Values:
#  radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# concave_pts_mean     0
# symmetry_mean        0
# fractal_dim_mean     0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# concave_pts_se       0
# symmetry_se          0
# fractal_dim_se       0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# concave_pts_worst    0
# symmetry_worst       0
# fractal_dim_worst    0
# diagnosis            0
# dtype: int64

# %% [markdown]
# ## ***Remove duplicate data***

# %%
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
data_cleaned = data_cleaned.drop_duplicates()
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# ## ***Saving the cleaned dataset***

# %%
data_cleaned.to_csv('cleaned_data.csv', index=False)

# %%
data = pd.read_csv('cleaned_data.csv')
numeric_data = data.select_dtypes(include=[np.number])
numeric_data.corr()
# Out:
#                    radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean           1.000000      0.323782        0.997855   0.987357
# texture_mean          0.323782      1.000000        0.329533   0.321086
# perimeter_mean        0.997855      0.329533        1.000000   0.986507
# area_mean             0.987357      0.321086        0.986507   1.000000
# smoothness_mean       0.170581     -0.023389        0.207278   0.177028
# compactness_mean      0.506124      0.236702        0.556936   0.498502
# concavity_mean        0.676764      0.302418        0.716136   0.685983
# concave_pts_mean      0.822529      0.293464        0.850977   0.823269
# symmetry_mean         0.147741      0.071401        0.183027   0.151293
# fractal_dim_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se             0.679090      0.275869        0.691765   0.732562
# texture_se           -0.097317      0.386358       -0.086761  -0.066280
# ...

# %%
plt.hist(data['diagnosis'], color='m')
plt.title('Plot_Diagnosis (M=1 , B=0)')
# B = Benign tumor
# M = malignant tumor
plt.show()

# %%
plt.figure(figsize=(20, 20))
cax = plt.imshow(numeric_data.corr(), cmap='coolwarm', interpolation='nearest')
plt.colorbar(cax)

plt.xticks(ticks=np.arange(len(numeric_data.corr().columns)), labels=numeric_data.corr().columns,rotation = 90)
plt.yticks(ticks=np.arange(len(numeric_data.corr().columns)), labels=numeric_data.corr().columns)
for i in range(len(numeric_data.corr().columns)):
    for j in range(len(numeric_data.corr().columns)):
        plt.text(j, i, f"{numeric_data.corr().iloc[i, j]:.2f}", ha='center', va='center', color='black')
plt.title('Correlation Heatmap')
plt.show()

# %%
color_map = {"B": "blue", "M": "red"}

plt.figure(figsize=(10, 6))
plt.scatter(data['radius_mean'], data['texture_mean'], c=data['diagnosis'].map(color_map), alpha=0.6)
plt.xlabel('Radius Mean')
plt.ylabel('Texture Mean')
plt.title('Scatter Plot of Radius Mean vs Texture Mean')
plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10, label='Non-Cancerous'),plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=10, label='Cancerous')], loc='upper left')
plt.grid(True)
plt.show()
